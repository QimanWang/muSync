# %%
# -*- coding: utf-8 -*-

import os

import google.oauth2.credentials

import google_auth_oauthlib.flow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google_auth_oauthlib.flow import InstalledAppFlow

# The CLIENT_SECRETS_FILE variable specifies the name of a file that contains
# the OAuth 2.0 information for this application, including its client_id and
# client_secret.
CLIENT_SECRETS_FILE = "tgt_client_secret.json"

# This OAuth 2.0 access scope allows for full read/write access to the
# authenticated user's account and requires requests to use an SSL connection.
SCOPES = ['https://www.googleapis.com/auth/youtube.force-ssl']
API_SERVICE_NAME = 'youtube'
API_VERSION = 'v3'

def get_authenticated_service():
  flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
  credentials = flow.run_console()
  return build(API_SERVICE_NAME, API_VERSION, credentials = credentials)

def print_response(response):
  print(response)

# Build a resource based on a list of properties given as key-value pairs.
# Leave properties with empty values out of the inserted resource.
def build_resource(properties):
  resource = {}
  for p in properties:
    # Given a key like "snippet.title", split into "snippet" and "title", where
    # "snippet" will be an object and "title" will be a property in that object.
    prop_array = p.split('.')
    ref = resource
    for pa in range(0, len(prop_array)):
      is_array = False
      key = prop_array[pa]

      # For properties that have array values, convert a name like
      # "snippet.tags[]" to snippet.tags, and set a flag to handle
      # the value as an array.
      if key[-2:] == '[]':
        key = key[0:len(key)-2:]
        is_array = True

      if pa == (len(prop_array) - 1):
        # Leave properties without values out of inserted resource.
        if properties[p]:
          if is_array:
            ref[key] = properties[p].split(',')
          else:
            ref[key] = properties[p]
      elif key not in ref:
        # For example, the property is "snippet.title", but the resource does
        # not yet have a "snippet" object. Create the snippet object here.
        # Setting "ref = ref[key]" means that in the next time through the
        # "for pa in range ..." loop, we will be setting a property in the
        # resource's "snippet" object.
        ref[key] = {}
        ref = ref[key]
      else:
        # For example, the property is "snippet.description", and the resource
        # already has a "snippet" object.
        ref = ref[key]
  return resource

# Remove keyword arguments that are not set
def remove_empty_kwargs(**kwargs):
  good_kwargs = {}
  if kwargs is not None:
    for key, value in kwargs.items():
      if value:
        good_kwargs[key] = value
  return good_kwargs

def videos_rate(client, **kwargs):
  # See full sample for function
  kwargs = remove_empty_kwargs(**kwargs)

  response = client.videos().rate(
    **kwargs
  ).execute()

  return print_response(response)


if __name__ == '__main__':
  # When running locally, disable OAuthlib's HTTPs verification. When
  # running in production *do not* leave this option enabled.
  os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
  client = get_authenticated_service()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=152975099980-06hgc3tih63p5a0mdi9so5r6cmua87ps.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyoutube.force-ssl&state=rQ3sj1GflBwhqcUqkBzM5ehzi1Zw3v&prompt=consent&access_type=offline
# Enter the authorization code: 4/BQFLUOMS4rO6cyeKbctze1R_la1cwKMyIm1GvOx2PMaDzJsd6bSEImM

# %%
def videos_rate(client, **kwargs):
  # See full sample for function
  kwargs = remove_empty_kwargs(**kwargs)

  response = client.videos().rate(
    **kwargs
  ).execute()

  return response

# %%
  z= videos_rate(client,
    id='YkLyTXJYwgI',
    rating='like')

# %%
z
# Out:
# ''

# %%
def videos_list_my_rated_videos(client, **kwargs):
    # See full sample for function
    kwargs = remove_empty_kwargs(**kwargs)

    response = client.videos().list(
        **kwargs
    ).execute()

    return response

# %%
r = videos_list_my_rated_videos(client,
                                        part='snippet,contentDetails,statistics',
                                        myRating='like')

# %%
r['pageInfo']
# Out:
# {'totalResults': 198, 'resultsPerPage': 5}

# %%
import csv
with open('liked_videos.csv') as infile:
    csv_reader = csv.reader(infile, delimiter=',')
    next(csv_reader)
    for row in csv_reader:
        print(row[0])
        z= videos_rate(client,
        id=row[0],
        rating='like')
# Out:
# s9WQbnaMR0c
# KGrulNiJ6Uc
# Oayma-ggbUk
# -0bspXmDI7E
# nQWFzMvCfLE
# 3_g2un5M350
# sIaT8Jl2zpI
# jIzOIsQWMfg
# av5JD1dfj_c
# r_Q2ZtrJmwM
# TMB6-YflpA4
# gdGdO6KjF1I
# AlIEogRBK_I
# TU2hbd1QJnA
# _lZlhTeY5Yc
# E9-HjAr034M
# 6kn4SHi5KUs
# Yqw6c5R_KAs
# qJoAS4kZEDk
# iqPYzVxK62Y
# 9KvCJi7t2DE
# IDyQO0QuvKY
# 5Lq1IOCCzkI
# vTMAa6zZ7jY
# gk0nB9vvYfU
# tQjsAJhsSw8
# AaxFIY-cWH0
# K6STm-fcu6c
# ayLK9ZD5w0s
# qtgf-sidZrU
# Yc2ED_dPPhc
# 0tTn95TLIaw
# SJOgTMP8cs4
# 5XK2C9w6oVk
# K4DyBUG242c
# BsvIwqyiaJw
# Y2ge3KrdeWs
# gvF-G2qKNxI
# cVZmZzI1YEs
# UXTEJhIr6IY
# hbNFS2u2ixk
# r02d18m-maM
# s-VFpsrbWLk
# h-woMj_Vt0A
# 27R6ZavdzzQ
# JMtE8CnDpd0
# -M4CUPBH5bg
# azs0_ErHLXE
# m6kiNlnJ2Uk
# xxIr3dbOJxU
# E-jOV1i7YQs
# 3FNtomLbKUg
# OJBxNA8cX-E
# PQjovLrnvVo
# YSr3vtB-wvU
# A7UU9Z4h56E
# n-hy9MswmcA
# U60_PkV47b0
# EiGtnhdzIXc
# p3KySSDKUhY
# P8uJ4gFjJGE
# Amz4fHUapLk
# k6ML9oIXHco
# 8TyIAVmovDo
# zOEISgh7k_g
# MPvhmneqUvE
# aYlXNpaQydk
# Q4fYtFmoWDk
# YyWru2XOiK0
# R5y0IhWDU-g
# w4nihuYVTW0
# 3AIII5SN0N0
# S3Q966mgeSc
# F6VfsJ7LAlE
# tRa3fOlnN7k
# E-VVL49KQlM
# yjWwfDW9IoA
# vQs46lQi6jk
# wLtk3-b5pZ8
# cH0SDpPgbPc
# _4u3CjMDb0s
# MJMfU2Od2T8
# pYwERJKWez8
# KL_x1dC8P5c
# XsQ0jN-SnmQ
# HWhhMKXAFpo
# Vc8xup0UzPE
# 8Q6K43alRDo
# ldDC73hob2I
# Eww37rpEyfs
# vQaiRSgq2Cc
# 5uEVbzD_Ta4
# TNWMZIf7eSg
# nM0xDI5R50E
# x2MJXrCaAYY
# eLTFJOA2C_E
# rcwJvgs53Ng
# CbNmRJCkwQs
# WZrLs9hto04
# HYaYTxRK0lU
# kNjT7VAq0Bs
# nxvm4P0jFKY
# Ew4VvF0DPMc
# wFtBcoZ76Uk
# dBrRBZy8OTs
# aw50xPhFtd4
# Y7DgZFurtIQ
# 82t_UOMHPJY
# qH1wbp-FASo
# _L-9APlTc6M
# UL4xVMtXP8k
# Zgny6lBHmQc
# u94VpYq0RIw
# IxLV7M1sdjg
# g087JgMc9D4
# o9eYJbehU7Q
# 8WqEp8nbgPg
# scS64l3wvew
# xPvwDcrT6rU
# _H7ZG7yk5Wo
# RuQgrjLkoho
# 6JO1V-bCh04
# 2xTy-tklthw
# ZLTbB_qqBHo
# _JerwGfJ1ro
# H6SShCF58-U
# j0XAlXNPKlI
# T_rUtj0Ifos
# AYN5Gf2gCF4
# c2j_yc5IBBs
# VhHQyb4r9Xg
# 7WxQABP_V_Q
# vtplb9UOfYQ
# uweOiH7ioKw
# WC2XFhRohRc
# eiJ0cYjx2eg
# --zku6TB5NY
# Fzr40i_Sh58
# mKYWLqAvdzU
# Y8iv4z5wJOk
# 0SGSizfLVow
# ZCJ8wbFNKXA
# Oa49Nym7wJk
# TvSLCxXyrBA
# hgIDXTmmgDg
# qL82-MmT8RA
# rPg8db2GJYM
# ELScjuBfGYQ
# mrJW7HwbRC4
# -K4dc7861Rs
# lTfQ-EKHrx8
# N9yS6lll1rk
# 5FK0qCEQ3L0
# z9drIRdLh88
# qf09H2xFq2s
# KkOF8UiB7u8
# jEN_mymgfms
# G97_rOdHcnY
# VRK6ESjlc-c
# timiyUIdTyc
# AxD3dLKRgk4
# HQhOhO3JSG0
# teYRTeI2yJY
# 9_zhRU93Udo
# YkLyTXJYwgI
# FuDdstaZXdw
# HTPRLsWMbKI
# ULcmgv837MQ
# w41gqTFYh08
# WUOzgEpVHWw
# kfXdP7nZIiE
# SewFDOy3d5A
# 4RtqzOs14Iw
# GKF5zbixFFQ
# q3G-DtrVlAE
# COu9-L9jmCY
# q_oD7Ay_SfM
# El2KPBO-_uk
# vdXsLt0o_9g
# 48ydDUQ16RE
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-46-fd5341cda9ae> in <module>
#       7         z= videos_rate(client,
#       8         id=row[0],
# ----> 9         rating='like')
#      10
#      11
#
# <ipython-input-11-7171a1df5399> in videos_rate(client, **kwargs)
#       4
#       5   response = client.videos().rate(
# ----> 6     **kwargs
#       7   ).execute()
#       8
#
# ~/anaconda3/lib/python3.7/site-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131         return positional_wrapper
#     132
#
# ~/anaconda3/lib/python3.7/site-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     849       callback(resp)
#     850     if resp.status >= 300:
# --> 851       raise HttpError(resp, content, uri=self.uri)
#     852     return self.postproc(resp, content)
#     853
#
# HttpError: <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/videos/rate?id=48ydDUQ16RE&rating=like returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.">
