# %%
import requests

# %%
# get channel id
url ="https://www.googleapis.com/youtube/v3/channels/"
params={
    "part":"snippet,contentDetails,statistics",
     "forUsername":"myqiman",
   "key":"AIzaSyDZs1os43nzh_eESFC6tvZr9rjcBfwwa0"
}
# the above key has been modified, to decode, san hou mian jia ni zhidaode
r= requests.get(url,params)
r.json()
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Rbs3vRhbuTNmMUK0tjU9nNQGW5Y"',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/djr3KBe3d-cvw5sPui5WEDVj-PY"',
#    'id': 'UCCM7hkeIXVe9KQi9i9H57lw',
#    'snippet': {'title': 'qiman wang',
#     'description': '',
#     'customUrl': 'MyQiman',
#     'publishedAt': '2012-01-17T04:53:12.000Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a-/AAuE7mCKb9mRSjn7rXjkGP2R6azVn2qO2hBAfYNjWw=s88-mo-c-c0xffffffff-rj-k-no',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/a-/AAuE7mCKb9mRSjn7rXjkGP2R6azVn2qO2hBAfYNjWw=s240-mo-c-c0xffffffff-rj-k-no',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/a-/AAuE7mCKb9mRSjn7rXjkGP2R6azVn2qO2hBAfYNjWw=s800-mo-c-c0xffffffff-rj-k-no',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'qiman wang', 'description': ''}},
#    'contentDetails': {'relatedPlaylists': {'likes': 'LLCM7hkeIXVe9KQi9i9H57lw',
#      'favorites': 'FLCM7hkeIXVe9KQi9i9H57lw',
#      'uploads': 'UUCM7hkeIXVe9KQi9i9H57lw',
#      'watchHistory': 'HL',
#      'watchLater': 'WL'}},
#    'statistics': {'viewCount': '18498',
#     'commentCount': '0',
#     'subscriberCount': '56',
#     'hiddenSubscriberCount': False,
#     'videoCount': '43'}}]}

# %%
url = "https://www.googleapis.com/youtube/v3/playlists"

# %%
params={
    "part":"snippet,contentDetails",
     "channelId":"UC_x5XG1OV2P6uZZ5FSM9Ttw",
   "maxResults":"25",
   "key":"AIzaSyDZs1os43Qnzh_eESFC6tvZr9rjcBfwwa0"
}
#UCCM7hkeIXVe9KQi9i9H57lw

# %%
r= requests.get(url,params)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'kind': 'youtube#playlistListResponse',
#  'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/5IPIAaRbIxSlSaMqYl29MF6zkBc"',
#  'nextPageToken': 'CBkQAA',
#  'pageInfo': {'totalResults': 400, 'resultsPerPage': 25},
#  'items': [{'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/yJ9I_qA_6Rjb9rGF-45QSTbRBl4"',
#    'id': 'PLOU2XLYxmsIJHzqd4MS_tHLtZ3ZtS44lN',
#    'snippet': {'publishedAt': '2019-01-29T06:42:46.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Google Dev vids with Hindi subtitles!',
#     'description': 'This playlist contains various Google Developer videos that are subtitled in Hindi. \n\nTo view Hindi subtitles on any of these videos, please use the "CC" button at the bottom of the YouTube video player.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/as3pQTuyTgY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/as3pQTuyTgY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/as3pQTuyTgY/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/as3pQTuyTgY/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/as3pQTuyTgY/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Google Dev vids with Hindi subtitles!',
#      'description': 'This playlist contains various Google Developer videos that are subtitled in Hindi. \n\nTo view Hindi subtitles on any of these videos, please use the "CC" button at the bottom of the YouTube video player.'}},
#    'contentDetails': {'itemCount': 91}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/CF1Jddx5fkob0KYw7lr62nXqd68"',
#    'id': 'PLOU2XLYxmsIJ3JNXox3w0NLQ20KPI18n8',
#    'snippet': {'publishedAt': '2019-01-23T18:30:09.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Flutter Live 2018 Keynote',
#     'description': 'This playlist contains the keynote from Flutter Live, hosted at the Science Museum in London on December 4th 2018. Watch the Flutter Live talks to experience the latest from Flutter, Google’s free and open source SDK for building high-quality native iOS and Android apps from a single codebase.\n\nFind more info on the event website → https://g.co/FlutterLive\n\nSubscribe to the channel! → https://bit.ly/Google-Developers',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kpcjBD1XDwU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kpcjBD1XDwU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kpcjBD1XDwU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/kpcjBD1XDwU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/kpcjBD1XDwU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Flutter Live 2018 Keynote',
#      'description': 'This playlist contains the keynote from Flutter Live, hosted at the Science Museum in London on December 4th 2018. Watch the Flutter Live talks to experience the latest from Flutter, Google’s free and open source SDK for building high-quality native iOS and Android apps from a single codebase.\n\nFind more info on the event website → https://g.co/FlutterLive\n\nSubscribe to the channel! → https://bit.ly/Google-Developers'}},
#    'contentDetails': {'itemCount': 4}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/z1kDsAU3YmJhiVhanWjm9yQgJFs"',
#    'id': 'PLOU2XLYxmsIKjax22V87t1Yi-9Es040GH',
#    'snippet': {'publishedAt': '2019-01-17T22:12:02.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Engineering Everyday Equity',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oSmCTqX9fRA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/oSmCTqX9fRA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/oSmCTqX9fRA/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/oSmCTqX9fRA/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/oSmCTqX9fRA/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Engineering Everyday Equity', 'description': ''}},
#    'contentDetails': {'itemCount': 3}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/8uNjUwRJiKlPa_EwhzqdtZPYH2c"',
#    'id': 'PLOU2XLYxmsIJ1AJ_AAd3qptC1h6INtTFr',
#    'snippet': {'publishedAt': '2018-12-18T23:24:33.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Conversation Design',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/D5WkP8JZgdw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/D5WkP8JZgdw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/D5WkP8JZgdw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/D5WkP8JZgdw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/D5WkP8JZgdw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Conversation Design', 'description': ''}},
#    'contentDetails': {'itemCount': 3}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/dvlHSbW_eE8_tQ6bJ8HH3fjr1y0"',
#    'id': 'PLOU2XLYxmsILq4ysYNWXq5TOGLgYDJgVD',
#    'snippet': {'publishedAt': '2018-11-20T18:47:10.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Flutter Live 2018 - All Talks',
#     'description': 'This playlist contains all video content from Flutter Live, hosted at the Science Museum in London on December 4th 2018. Watch the Flutter Live talks to experience the latest from Flutter, Google’s free and open source SDK for building high-quality native iOS and Android apps from a single codebase.\n\nFind more info on the event website → https://g.co/FlutterLive\n\nSubscribe to the channel! → https://bit.ly/Google-Developers',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/D-o4BqJxmJE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/D-o4BqJxmJE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/D-o4BqJxmJE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Flutter Live 2018 - All Talks',
#      'description': 'This playlist contains all video content from Flutter Live, hosted at the Science Museum in London on December 4th 2018. Watch the Flutter Live talks to experience the latest from Flutter, Google’s free and open source SDK for building high-quality native iOS and Android apps from a single codebase.\n\nFind more info on the event website → https://g.co/FlutterLive\n\nSubscribe to the channel! → https://bit.ly/Google-Developers'}},
#    'contentDetails': {'itemCount': 22}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/R__K0AEUzNXDg2v9ts-TnNmSS-E"',
#    'id': 'PLOU2XLYxmsIJyiwUPCou_OVTpRIn_8UMd',
#    'snippet': {'publishedAt': '2018-11-05T19:41:46.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Flutter Widgets 101',
#     'description': 'The following are covered in this Flutter Widgets series. \n\n→ How to Create Stateless Widgets\n→ How Stateful Widgets Are Used Best\n→ Inherited Widgets Explained\n→ When to Use Keys',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CXedqMlLo7M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/CXedqMlLo7M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/CXedqMlLo7M/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/CXedqMlLo7M/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/CXedqMlLo7M/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Flutter Widgets 101',
#      'description': 'The following are covered in this Flutter Widgets series. \n\n→ How to Create Stateless Widgets\n→ How Stateful Widgets Are Used Best\n→ Inherited Widgets Explained\n→ When to Use Keys'}},
#    'contentDetails': {'itemCount': 5}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/MVi7SztmN_g40DLqq8bsQxyN5Fc"',
#    'id': 'PLOU2XLYxmsILACK8NF7UHElmmZzudR7c7',
#    'snippet': {'publishedAt': '2018-10-19T02:42:26.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Sessions on Flutter',
#     'description': 'Watch technical deep dives on building native apps with Flutter\n\nGet started at https://flutter.io/',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hA0hrpR-o8U/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hA0hrpR-o8U/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hA0hrpR-o8U/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/hA0hrpR-o8U/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/hA0hrpR-o8U/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Sessions on Flutter',
#      'description': 'Watch technical deep dives on building native apps with Flutter\n\nGet started at https://flutter.io/'}},
#    'contentDetails': {'itemCount': 7}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/A_tLUU97pRQzvyZP3Nr-RPAnpQg"',
#    'id': 'PLOU2XLYxmsII5MlZ8YfAwOMg5w3CaF7n9',
#    'snippet': {'publishedAt': '2018-09-28T05:19:09.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Get Excited for Flutter Live 2018!',
#     'description': 'Build beautiful native apps in record time\n\nFlutter is Google’s mobile app SDK for crafting high-quality native interfaces on iOS and Android in record time. Flutter works with existing code, is used by developers and organizations around the world, and is free and open source.\n\nGet started at https://flutter.io/',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jtYk3gWRSw0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jtYk3gWRSw0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/jtYk3gWRSw0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/jtYk3gWRSw0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/jtYk3gWRSw0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Get Excited for Flutter Live 2018!',
#      'description': 'Build beautiful native apps in record time\n\nFlutter is Google’s mobile app SDK for crafting high-quality native interfaces on iOS and Android in record time. Flutter works with existing code, is used by developers and organizations around the world, and is free and open source.\n\nGet started at https://flutter.io/'}},
#    'contentDetails': {'itemCount': 18}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/GNUnL7FqeOAhguEIlun-xf-4IRs"',
#    'id': 'PLOU2XLYxmsIK_ZeW1fh49iu5-j2D99O-P',
#    'snippet': {'publishedAt': '2018-09-13T20:45:26.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Flutter Tutorials',
#     'description': 'This playlist contains tutorials and best practices for developing with Flutter.\n\nFlutter is Google’s mobile app SDK for crafting high-quality native interfaces on iOS and Android in record time. Flutter works with existing code, is used by developers and organizations around the world, and is free and open source.\n\nYou can get started here → http://bit.ly/2MvqGVE\n\nSubscribe to the Google Developers channel → http://goo.gl/mQyv5L',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/W1pNjxmNHNQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/W1pNjxmNHNQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/W1pNjxmNHNQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/W1pNjxmNHNQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/W1pNjxmNHNQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Flutter Tutorials',
#      'description': 'This playlist contains tutorials and best practices for developing with Flutter.\n\nFlutter is Google’s mobile app SDK for crafting high-quality native interfaces on iOS and Android in record time. Flutter works with existing code, is used by developers and organizations around the world, and is free and open source.\n\nYou can get started here → http://bit.ly/2MvqGVE\n\nSubscribe to the Google Developers channel → http://goo.gl/mQyv5L'}},
#    'contentDetails': {'itemCount': 3}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/-q64pwZLSxmCaNHLcYD7WVgH2l4"',
#    'id': 'PLOU2XLYxmsIJ7imRl4jU7623pHNjZqw3t',
#    'snippet': {'publishedAt': '2018-08-31T16:03:59.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Mobile Ads Garage : Season 2',
#     'description': 'Welcome to the Mobile Ads Garage, a YouTube series where we’ll show you the nuts and bolts of the Google Mobile Ads SDK and the best ways to monetize your apps while keeping users happy.\n\nTo skip the iOS implementation and go straight to Android, please follow this link: https://goo.gl/UD0VPV\n\nAdMob Quick Start iOS: https://goo.gl/XU1pha\nAdMob Quick Start Android: https://goo.gl/FwyxaR\nSample Code for iOS: https://goo.gl/7kPvqT\nSample Code for Android: https://goo.gl/mG4VnS',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vfsgBBky4bg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vfsgBBky4bg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vfsgBBky4bg/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/vfsgBBky4bg/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/vfsgBBky4bg/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Mobile Ads Garage : Season 2',
#      'description': 'Welcome to the Mobile Ads Garage, a YouTube series where we’ll show you the nuts and bolts of the Google Mobile Ads SDK and the best ways to monetize your apps while keeping users happy.\n\nTo skip the iOS implementation and go straight to Android, please follow this link: https://goo.gl/UD0VPV\n\nAdMob Quick Start iOS: https://goo.gl/XU1pha\nAdMob Quick Start Android: https://goo.gl/FwyxaR\nSample Code for iOS: https://goo.gl/7kPvqT\nSample Code for Android: https://goo.gl/mG4VnS'}},
#    'contentDetails': {'itemCount': 1}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/P9xnmHc3sRYl6uNi_IP7AgLfjjI"',
#    'id': 'PLOU2XLYxmsIJmK5zI45XAye_ymCwj68MO',
#    'snippet': {'publishedAt': '2018-08-27T19:25:18.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Developer Student Club Leads',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AAin71VkbzQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AAin71VkbzQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AAin71VkbzQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/AAin71VkbzQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/AAin71VkbzQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Developer Student Club Leads', 'description': ''}},
#    'contentDetails': {'itemCount': 2}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/0s31AU6r0yXL5wYl8-Ep_c3K45k"',
#    'id': 'PLOU2XLYxmsIL0pH0zWe_ZOHgGhZ7UasUE',
#    'snippet': {'publishedAt': '2018-08-14T17:02:59.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Flutter Widget of the Week',
#     'description': 'Get your weekly Flutter widget tips here!\n\nGet started with Flutter → flutter.io',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lkF0TQJO0bA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lkF0TQJO0bA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lkF0TQJO0bA/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/lkF0TQJO0bA/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/lkF0TQJO0bA/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Flutter Widget of the Week',
#      'description': 'Get your weekly Flutter widget tips here!\n\nGet started with Flutter → flutter.io'}},
#    'contentDetails': {'itemCount': 26}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/N_1YmWBqJP54EiaTxN50zHUMHmU"',
#    'id': 'PLOU2XLYxmsILhFpQQzS8zo8mc86IRNqMa',
#    'snippet': {'publishedAt': '2018-06-29T21:24:09.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'PAIR UX Symposium 2018',
#     'description': "Welcome to our People + AI Research Initiative UX Symposium at Google, a forum to discuss pressing topics in human + AI interaction. We've brought together academics, researchers and artists to discuss model interpretability, augmented intelligence, inclusivity and human–AI collaboration. Watch all the talks here in this playlist.\n\nSubscribe to the Google Developers channel → http://goo.gl/mQyv5L",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CsA1TQVcVB4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/CsA1TQVcVB4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/CsA1TQVcVB4/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/CsA1TQVcVB4/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/CsA1TQVcVB4/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'PAIR UX Symposium 2018',
#      'description': "Welcome to our People + AI Research Initiative UX Symposium at Google, a forum to discuss pressing topics in human + AI interaction. We've brought together academics, researchers and artists to discuss model interpretability, augmented intelligence, inclusivity and human–AI collaboration. Watch all the talks here in this playlist.\n\nSubscribe to the Google Developers channel → http://goo.gl/mQyv5L"}},
#    'contentDetails': {'itemCount': 10}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/rsr3IkBITn_w83ixiRBzsezsS8I"',
#    'id': 'PLOU2XLYxmsIK0r_D-zWcmJ1plIcDNnRkK',
#    'snippet': {'publishedAt': '2018-06-14T23:25:28.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'The Boring Flutter Development Show',
#     'description': 'Welcome to The Boring Flutter Development Show. Watch Google Engineers build apps from scratch in Flutter, including all the dead ends, blunders, and runtime errors.\n\nGet started with Flutter → https://flutter.io\nTry a Flutter codelab → https://goo.gl/d3fHPo\nJoin the conversation → https://goo.gl/68oUnb',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yr8F2S3Amas/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yr8F2S3Amas/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yr8F2S3Amas/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/yr8F2S3Amas/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/yr8F2S3Amas/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'The Boring Flutter Development Show',
#      'description': 'Welcome to The Boring Flutter Development Show. Watch Google Engineers build apps from scratch in Flutter, including all the dead ends, blunders, and runtime errors.\n\nGet started with Flutter → https://flutter.io\nTry a Flutter codelab → https://goo.gl/d3fHPo\nJoin the conversation → https://goo.gl/68oUnb'}},
#    'contentDetails': {'itemCount': 23}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/NNqnsxk4oOuph3yf_hCDb6Y2e1E"',
#    'id': 'PLOU2XLYxmsIL-iJMv7w0Gj1rLXMcv-f95',
#    'snippet': {'publishedAt': '2018-06-11T23:16:38.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Build rich conversational experiences with Dialogflow',
#     'description': 'Learn about Dialogflow and how you can use the NLU tool to build ML-powered conversational experiences, such as voice apps and chatbots, to interact with users in new ways.\n\nSubscribe to the Dialogflow channel for more content like this → https://goo.gl/gN2sz8',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yT58gTXdQb8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yT58gTXdQb8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yT58gTXdQb8/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/yT58gTXdQb8/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/yT58gTXdQb8/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Build rich conversational experiences with Dialogflow',
#      'description': 'Learn about Dialogflow and how you can use the NLU tool to build ML-powered conversational experiences, such as voice apps and chatbots, to interact with users in new ways.\n\nSubscribe to the Dialogflow channel for more content like this → https://goo.gl/gN2sz8'}},
#    'contentDetails': {'itemCount': 4}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/WpsNZUKZ9qlcT5sB22u5MXzskmg"',
#    'id': 'PLOU2XLYxmsIJ7dsVN4iRuA7BT8XHzGtCr',
#    'snippet': {'publishedAt': '2018-05-22T17:23:45.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Flutter by Google',
#     'description': 'Get started at https://flutter.io today.\n\nFlutter is Google’s mobile UI framework for crafting high-quality native interfaces on iOS and Android in record time. Flutter works with existing code, is used by developers and organizations around the world, and is free and open source.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fq4N0hgOWzU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fq4N0hgOWzU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fq4N0hgOWzU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/fq4N0hgOWzU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/fq4N0hgOWzU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Flutter by Google',
#      'description': 'Get started at https://flutter.io today.\n\nFlutter is Google’s mobile UI framework for crafting high-quality native interfaces on iOS and Android in record time. Flutter works with existing code, is used by developers and organizations around the world, and is free and open source.'}},
#    'contentDetails': {'itemCount': 82}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/m2FYqZD74Xme5sKiRv_lOW3w0cU"',
#    'id': 'PLOU2XLYxmsIKiu-I6EQL-as514X1q62zX',
#    'snippet': {'publishedAt': '2018-05-14T20:57:48.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Inspirational Keynotes from Google I/O 2018',
#     'description': 'This playlist contains inspirational keynote sessions from Google I/O 2018. Learn about designing with everyone in mind, the future of computing, and how AI & ML are supercharging innovation across many different industries. \n\nGoogle I/O 2018 all sessions playlist: https://goo.gl/Dn7tra',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Azt8Nc-mtKM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Azt8Nc-mtKM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Azt8Nc-mtKM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Azt8Nc-mtKM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Azt8Nc-mtKM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Inspirational Keynotes from Google I/O 2018',
#      'description': 'This playlist contains inspirational keynote sessions from Google I/O 2018. Learn about designing with everyone in mind, the future of computing, and how AI & ML are supercharging innovation across many different industries. \n\nGoogle I/O 2018 all sessions playlist: https://goo.gl/Dn7tra'}},
#    'contentDetails': {'itemCount': 8}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/uZzuKeiaZGoA4U_hOsLxdi5cOGM"',
#    'id': 'PLOU2XLYxmsIKhkDJlVZfhYvEVR3Odt1y0',
#    'snippet': {'publishedAt': '2018-05-11T01:28:12.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Recaps from Google I/O 2018',
#     'description': "This playlist contains recaps of key sessions and topics presented at Google I/O 2018.\n\nSee all the sessions from Google I/O '18 here → https://goo.gl/q1Tr8x\n\nSubscribe to the Google Developers channel → http://goo.gl/mQyv5L\n\n#io18",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NeF0zpT4gNE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/NeF0zpT4gNE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/NeF0zpT4gNE/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/NeF0zpT4gNE/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/NeF0zpT4gNE/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Recaps from Google I/O 2018',
#      'description': "This playlist contains recaps of key sessions and topics presented at Google I/O 2018.\n\nSee all the sessions from Google I/O '18 here → https://goo.gl/q1Tr8x\n\nSubscribe to the Google Developers channel → http://goo.gl/mQyv5L\n\n#io18"}},
#    'contentDetails': {'itemCount': 7}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/7gV7PJD8smndU_8xSjv76EtTzxk"',
#    'id': 'PLOU2XLYxmsIJQgQfgYDuH8V31HZTtWUBp',
#    'snippet': {'publishedAt': '2018-05-09T18:27:03.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'IoT at Google I/O 2018',
#     'description': "This playlist contains all the I/O 2018 sessions related to the Internet of Things.\nLearn more on the I/O Website → https://goo.gl/1TjXUJ  \n\nSee all the sessions from Google I/O '18 here → https://g.co/io/videos\nSubscribe to the Google Developers channel → http://goo.gl/mQyv5L\n\n#io18",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/e_PI_Npb3-U/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/e_PI_Npb3-U/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/e_PI_Npb3-U/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/e_PI_Npb3-U/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/e_PI_Npb3-U/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'IoT at Google I/O 2018',
#      'description': "This playlist contains all the I/O 2018 sessions related to the Internet of Things.\nLearn more on the I/O Website → https://goo.gl/1TjXUJ  \n\nSee all the sessions from Google I/O '18 here → https://g.co/io/videos\nSubscribe to the Google Developers channel → http://goo.gl/mQyv5L\n\n#io18"}},
#    'contentDetails': {'itemCount': 12}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/V08CeCfKQsECwCWODaCNO161D0s"',
#    'id': 'PLOU2XLYxmsIIjoHFYLtwS-_dKrtLhhk_D',
#    'snippet': {'publishedAt': '2018-05-08T15:22:57.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Google I/O 2018 Livestreams',
#     'description': 'This playlist contains all Google I/O 2018 livestreams. Each livestream description details a session schedule. \n\nAlso, you can find the full event schedule here (all times are PDT) → https://goo.gl/ZQce6g\n\nGoogle I/O 2018 All Sessions playlist → https://goo.gl/q1Tr8x\nSubscribe to the Google Developers channel → http://goo.gl/mQyv5L',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CGMOG_5tbxY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/CGMOG_5tbxY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/CGMOG_5tbxY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Google I/O 2018 Livestreams',
#      'description': 'This playlist contains all Google I/O 2018 livestreams. Each livestream description details a session schedule. \n\nAlso, you can find the full event schedule here (all times are PDT) → https://goo.gl/ZQce6g\n\nGoogle I/O 2018 All Sessions playlist → https://goo.gl/q1Tr8x\nSubscribe to the Google Developers channel → http://goo.gl/mQyv5L'}},
#    'contentDetails': {'itemCount': 21}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/dD96QORssgWBw5YU97CFJmdpn9Q"',
#    'id': 'PLOU2XLYxmsIKzJveaJfgBm6ifuV4N2PPM',
#    'snippet': {'publishedAt': '2018-05-07T18:37:37.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Design at Google I/O 2018',
#     'description': "This playlist contains all the I/O 2018 sessions related to Design.\nLearn more on the I/O Website → https://goo.gl/1TjXUJ  \n\nSee all the sessions from Google I/O '18 here → https://g.co/io/videos\nSubscribe to the Google Developers channel → http://goo.gl/mQyv5L\n\n#io18 #GoogleIO #GoogleIO2018",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3VUMl_l-_fI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3VUMl_l-_fI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3VUMl_l-_fI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/3VUMl_l-_fI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/3VUMl_l-_fI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Design at Google I/O 2018',
#      'description': "This playlist contains all the I/O 2018 sessions related to Design.\nLearn more on the I/O Website → https://goo.gl/1TjXUJ  \n\nSee all the sessions from Google I/O '18 here → https://g.co/io/videos\nSubscribe to the Google Developers channel → http://goo.gl/mQyv5L\n\n#io18 #GoogleIO #GoogleIO2018"}},
#    'contentDetails': {'itemCount': 14}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/MRjsgo-lmufdTlTrzq76zuqjJtM"',
#    'id': 'PLOU2XLYxmsIKRvTz5vtO2xKAgOoC-xw3Y',
#    'snippet': {'publishedAt': '2018-05-02T16:50:11.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Get excited for Google I/O 2018! 🎈 May 8-10th',
#     'description': 'Join us as we countdown to Google I/O 2018\nLearn everything about #io18 here → https://goo.gl/pZyd23\n\nThe Keynotes and most of the sessions will be livestreamed on the Google Developers channel → https://goo.gl/hy5Dt\n\nFollow the #io18journey of 5 attendees here → https://goo.gl/Kpqheg\n\nThis year’s developer festival will be held May 8-10 at the Shoreline Amphitheatre in Mountain View, CA. All the livestreams from I/O 2018 will be held on the Google Developers channel & all the sessions will be made available. Stay tuned for more information.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BEtPCT7ZcE0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BEtPCT7ZcE0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BEtPCT7ZcE0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/BEtPCT7ZcE0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/BEtPCT7ZcE0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Get excited for Google I/O 2018! 🎈 May 8-10th',
#      'description': 'Join us as we countdown to Google I/O 2018\nLearn everything about #io18 here → https://goo.gl/pZyd23\n\nThe Keynotes and most of the sessions will be livestreamed on the Google Developers channel → https://goo.gl/hy5Dt\n\nFollow the #io18journey of 5 attendees here → https://goo.gl/Kpqheg\n\nThis year’s developer festival will be held May 8-10 at the Shoreline Amphitheatre in Mountain View, CA. All the livestreams from I/O 2018 will be held on the Google Developers channel & all the sessions will be made available. Stay tuned for more information.'}},
#    'contentDetails': {'itemCount': 38}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Rl-w_atBn3hErvATb3DmN5989xs"',
#    'id': 'PLOU2XLYxmsIKgHNoVIE3irXBy-pCCKbAS',
#    'snippet': {'publishedAt': '2018-04-26T19:18:31.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': '#io18journey - Google I/O 2018',
#     'description': "In this series, we follow 5 attendees of Google I/O 2018. They’ll be vlogging from the start of their journey in their home country through to their arrival at the Shoreline Amphitheatre in California. \n\nTune in here as Ann, Ire, Kseniia, Siraj, and Technical Guruji #ShareTheJourney with you!\n\n\nFor more information, check them out below!\n\nAnn Makosinski - is an inventor and former Google Science Fair winner\ngoo.gl/B9TF6f\n\nIre Aderinokun - is Nigeria's first ever female Google Developer Expert \nhttps://twitter.com/ireaderinokun\n\nKseniia Shumelchyk - lead organiser for Women Techmakers and Google Developer Group in Dnipro, Ukraine\nhttps://twitter.com/kseniias\n\nSiraj Raval - bringing AI education to the Youtube generation\nhttps://www.youtube.com/c/SirajRaval\n\nTechnical Guruji - Youtube tech expert specializing in Hindi-first content\ngoo.gl/6TUotD\n\n\nSubscribe to the Google Developers Channel → http://goo.gl/mQyv5L",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/c5QjFjwV_SM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/c5QjFjwV_SM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/c5QjFjwV_SM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/c5QjFjwV_SM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/c5QjFjwV_SM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': '#io18journey - Google I/O 2018',
#      'description': "In this series, we follow 5 attendees of Google I/O 2018. They’ll be vlogging from the start of their journey in their home country through to their arrival at the Shoreline Amphitheatre in California. \n\nTune in here as Ann, Ire, Kseniia, Siraj, and Technical Guruji #ShareTheJourney with you!\n\n\nFor more information, check them out below!\n\nAnn Makosinski - is an inventor and former Google Science Fair winner\ngoo.gl/B9TF6f\n\nIre Aderinokun - is Nigeria's first ever female Google Developer Expert \nhttps://twitter.com/ireaderinokun\n\nKseniia Shumelchyk - lead organiser for Women Techmakers and Google Developer Group in Dnipro, Ukraine\nhttps://twitter.com/kseniias\n\nSiraj Raval - bringing AI education to the Youtube generation\nhttps://www.youtube.com/c/SirajRaval\n\nTechnical Guruji - Youtube tech expert specializing in Hindi-first content\ngoo.gl/6TUotD\n\n\nSubscribe to the Google Developers Channel → http://goo.gl/mQyv5L"}},
#    'contentDetails': {'itemCount': 7}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/I0oVZLpe0eFd61VM4dXGfJo3jhU"',
#    'id': 'PLOU2XLYxmsILzpybwAE_RVDdvaohfOXm2',
#    'snippet': {'publishedAt': '2018-04-24T22:46:43.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'The Google Assistant and Actions on Google at Google I/O 2018',
#     'description': "This playlist contains all the I/O 2018 sessions related to the Google Assistant and Actions on Google.\nLearn more on the I/O Website → https://goo.gl/1TjXUJ  \n\nSee all the sessions from Google I/O '18 here → https://goo.gl/WdYG2e\nSubscribe to the Google Developers channel → http://goo.gl/mQyv5L\n\n#io18 #GoogleIO #GoogleIO2018",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1MhYTvHSv8U/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1MhYTvHSv8U/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1MhYTvHSv8U/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/1MhYTvHSv8U/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/1MhYTvHSv8U/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'The Google Assistant and Actions on Google at Google I/O 2018',
#      'description': "This playlist contains all the I/O 2018 sessions related to the Google Assistant and Actions on Google.\nLearn more on the I/O Website → https://goo.gl/1TjXUJ  \n\nSee all the sessions from Google I/O '18 here → https://goo.gl/WdYG2e\nSubscribe to the Google Developers channel → http://goo.gl/mQyv5L\n\n#io18 #GoogleIO #GoogleIO2018"}},
#    'contentDetails': {'itemCount': 17}},
#   {'kind': 'youtube#playlist',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/FrGaTRG4MqtpjEYPAV5ZSbeO7oI"',
#    'id': 'PLOU2XLYxmsIKqvy4t_7y2U0kTYrq9GO-I',
#    'snippet': {'publishedAt': '2018-04-24T22:43:42.000Z',
#     'channelId': 'UC_x5XG1OV2P6uZZ5FSM9Ttw',
#     'title': 'Accessibility at Google I/O 2018',
#     'description': "This playlist contains all the I/O 2018 sessions related to Accessibility.\nLearn more on the I/O Website → https://goo.gl/1TjXUJ \n\nSee all the sessions from Google I/O '18 here → https://goo.gl/WdYG2e\nSubscribe to the Google Developers channel → http://goo.gl/mQyv5L\n\n#io18 #GoogleIO #GoogleIO2018",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Lcoc4aCLfqI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Lcoc4aCLfqI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Lcoc4aCLfqI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Lcoc4aCLfqI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Lcoc4aCLfqI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Google Developers',
#     'localized': {'title': 'Accessibility at Google I/O 2018',
#      'description': "This playlist contains all the I/O 2018 sessions related to Accessibility.\nLearn more on the I/O Website → https://goo.gl/1TjXUJ \n\nSee all the sessions from Google I/O '18 here → https://goo.gl/WdYG2e\nSubscribe to the Google Developers channel → http://goo.gl/mQyv5L\n\n#io18 #GoogleIO #GoogleIO2018"}},
#    'contentDetails': {'itemCount': 4}}]}
